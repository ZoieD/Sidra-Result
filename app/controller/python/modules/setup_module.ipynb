# %%
import numpy as np
import pandas as pd
from keras.layers import Dense,Dropout,Activation,Input
from keras.models import Sequential,Model
from keras import metrics
# import tensorflowjs as tfjs
import matplotlib.pyplot as plt
import os
# Out:
# Using TensorFlow backend.

# %%
#model create
def make_model():
    model=Sequential()
    model.add(Dense(units=100,activation='relu',input_dim=6))
#     model.add(Dropout(0.05))
    model.add(Dense(units=80,activation='relu'))
    model.add(Dense(units=60, activation='relu'))
    model.add(Dense(units=40,activation='relu'))
    model.add(Dense(units=20,activation='relu'))
#     model.add(Dropout(0.05))
    model.add(Dense(units=1,activation=None))
    model.compile(loss='logcosh',optimizer='adam',metrics=[metrics.mae])
    print(model.summary())
    return model
model = make_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 100)               700
# _________________________________________________________________
# dense_2 (Dense)              (None, 80)                8080
# _________________________________________________________________
# dense_3 (Dense)              (None, 60)                4860
# _________________________________________________________________
# dense_4 (Dense)              (None, 40)                2440
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                820
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 21
# ...
# Total params: 16,921
# Trainable params: 16,921
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
df_train_pressure=pd.read_csv('../data_processer/pressure_data.csv')
df_train_impulses=pd.read_csv('../data_processer/impulses_data.csv')
x_train_pressure = df_train_pressure.drop('y',axis=1)
y_train_pressure = df_train_pressure['y']
x_train_impulses = df_train_impulses.drop('y',axis=1)
y_train_impulses = df_train_impulses['y']

# %%
model.fit(x_train_pressure, y_train_pressure, batch_size=50, epochs=1000, verbose=1)
# tfjs.converters.save_keras_model(model, './pressure_model.json')
model.save_weights('pressure_module.h5')
# Out:
# Epoch 1/1000
# 41200/41200 [==============================] - 1s 21us/step - loss: 1069.9975 - mean_absolute_error: 1070.6804
# Epoch 2/1000
# 41200/41200 [==============================] - 1s 21us/step - loss: 465.2507 - mean_absolute_error: 465.9285
# Epoch 3/1000
# 41200/41200 [==============================] - 1s 22us/step - loss: 432.0113 - mean_absolute_error: 432.6861
# Epoch 4/1000
# 41200/41200 [==============================] - 1s 21us/step - loss: 421.9177 - mean_absolute_error: 422.5943
# Epoch 5/1000
# 41200/41200 [==============================] - 1s 19us/step - loss: 411.1190 - mean_absolute_error: 411.7938
# Epoch 6/1000
# 41200/41200 [==============================] - 1s 19us/step - loss: 395.8350 - mean_absolute_error: 396.5092
# Epoch 7/1000
# 41200/41200 [==============================] - 1s 21us/step - loss: 360.8457 - mean_absolute_error: 361.5191
# Epoch 8/1000
# ...

# %%
model.fit(x_train_impulses, y_train_impulses, batch_size=80, epochs=200, verbose=1)
# tfjs.converters.save_keras_model(model, './')
model.save_weights('impulses_module.h5')
# Out:
# Epoch 1/200
# 37600/37600 [==============================] - 6s 164us/step - loss: 246.4417 - mean_absolute_error: 247.1215
# Epoch 2/200
# 37600/37600 [==============================] - 5s 137us/step - loss: 70.0140 - mean_absolute_error: 70.6796
# Epoch 3/200
# 37600/37600 [==============================] - 5s 134us/step - loss: 53.6449 - mean_absolute_error: 54.3038
# Epoch 4/200
# 37600/37600 [==============================] - 5s 136us/step - loss: 49.1704 - mean_absolute_error: 49.8262
# Epoch 5/200
# 37600/37600 [==============================] - 5s 134us/step - loss: 49.1355 - mean_absolute_error: 49.7900
# Epoch 6/200
# 37600/37600 [==============================] - 5s 141us/step - loss: 46.7925 - mean_absolute_error: 47.4439
# Epoch 7/200
# 37600/37600 [==============================] - 5s 129us/step - loss: 46.4098 - mean_absolute_error: 47.0600
# Epoch 8/200
# 37600/37600 [==============================] - 5s 123us/step - loss: 46.1593 - mean_absolute_error: 46.8125
# ...
